# %% [markdown]
# <a href="https://colab.research.google.com/github/paulandrea0/REP_FFT_AutoEncoder_Clas/blob/main/REP_FFT_Clasifica_comp_Z.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Set de datos**

# %% [markdown]
# El set de datos corresponde a señales de sismos volcánicos del tipo VT, LP y Tor

# %% [markdown]
# **1.1 Lectura de datos desde Google Drive**

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# Set de entrenamiento y validación para seãnales sísmicas en el componente Z

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import math

#%reset
df_test_1 = pd.read_csv('/gdrive/MyDrive/Sismos/VT_Z_teste.csv')
df_train_1 = pd.read_csv('/gdrive/MyDrive/Sismos/VT_Z_train.csv') 
df_test_2 = pd.read_csv('/gdrive/MyDrive/Sismos/LP_Z_teste.csv')
df_train_2 = pd.read_csv('/gdrive/MyDrive/Sismos/LP_Z_train.csv')
df_test_3 = pd.read_csv('/gdrive/MyDrive/Sismos/TOR_Z_teste.csv')
df_train_3 = pd.read_csv('/gdrive/MyDrive/Sismos/TOR_Z_train.csv')

# %% [markdown]
# **1.2 Aplicando función Mean para quitar el OffSet de los datos**
# Normalización a 3000 muestras por registro.

# %%
# Creando función para retirar el offset de los datos en DataFrame
def mean_norma(df_input):
        return df_input.apply(lambda x: (x-x.mean()), axis=1)  

df_mean_test_1 = mean_norma(df_test_1)  # Señales VT
df_mean_train_1 = mean_norma(df_train_1)
df_mean_test_2 = mean_norma(df_test_2)  # Señales LP
df_mean_train_2 = mean_norma(df_train_2)
df_mean_test_3 = mean_norma(df_test_3)  # Señales Tor
df_mean_train_3 = mean_norma(df_train_3)

print(df_mean_train_1.shape)
print(df_mean_test_1.shape)
print(df_mean_train_2.shape)
print(df_mean_test_2.shape)
print(df_mean_train_3.shape)
print(df_mean_test_3.shape)

# Convirtiendo el dataframe en array
d_train_1 = df_mean_train_1.values
d_train_1 = d_train_1[:, 0:3000]
d_test_1 = df_mean_test_1.values
d_test_1 = d_test_1[:, 0:3000]

d_train_2 = df_mean_train_2.values
d_train_2 = d_train_2[:, 0:3000]
d_test_2 = df_mean_test_2.values
d_test_2 = d_test_2[:, 0:6000]

d_train_3 = df_mean_train_3.values
d_train_3 = d_train_3[:, 0:3000]
d_test_3 = df_mean_test_3.values
d_test_3 = d_test_3[:, 0:3000]

# Dibujando la señal orioginal
n = 3000
fs = 50 # frecuencia de muestreo
t = np.linspace(0,fs,n)
plt.figure(1, figsize=(30, 4))
plt.subplot(231)
plt.plot(t, d_train_1[60])
plt.subplot(232)
plt.plot(t, d_train_2[18])
plt.subplot(233) 
plt.plot(t, d_train_3[38])
plt.subplot(234)
plt.plot(t, d_test_1[44])
plt.subplot(235)
plt.plot(t, d_test_2[34])
plt.subplot(236)
plt.plot(t, d_test_3[4])
# Out:
# (1480, 13348)
# (256, 10993)
# (362, 3000)
# (40, 3000)
# (61, 21494)
# (6, 27408)

# %% [markdown]
# **1.3 Eliminando valores NaN de los arreglos Numpy**

# %%
# Quitando los valores NaN de los array numpy

# Señales VT
d_train_1[np.isnan(d_train_1)] = 0.0
d_test_1[np.isnan(d_test_1)] = 0.0
print(d_train_1.shape)
print(d_test_1.shape)

# Señales LP
d_train_2[np.isnan(d_train_2)] = 0.0
d_test_2[np.isnan(d_test_2)] = 0.0
print(d_train_2.shape)
print(d_test_2.shape)

# Señales Tor`
d_train_3[np.isnan(d_train_3)] = 0.0
d_test_3[np.isnan(d_test_3)] = 0.0
print(d_train_3.shape)
print(d_test_3.shape)

# Graficando
plt.figure(2, figsize=(15, 4))
plt.subplot(231)
plt.plot(t, d_train_1[60])
plt.subplot(232)
plt.plot(t, d_train_2[18])
plt.subplot(233) 
plt.plot(t, d_train_3[38])
plt.subplot(234)
plt.plot(t, d_test_1[44])
plt.subplot(235)
plt.plot(t, d_test_2[34])
plt.subplot(236)
plt.plot(t, d_test_3[4])
# Out:
# (1480, 3000)
# (256, 3000)
# (362, 3000)
# (40, 3000)
# (61, 3000)
# (6, 3000)

# %% [markdown]
# **1.4 Aplicando transformada de Fourier al DataSet**

# %% [markdown]
# Al aplicar la transformada de Fourier a mis datos, estos pueden quedar reducidos a la mitad en cuanto a los elementos a ser presentados en la entrada del autoencoder, así mejorando el rendimiento. Además las carácterísticas a ser aprendidas por el modelo pueden resultar más claras.

# %%
import scipy.fft as sfft

# Transformada de Fourier
n2 = 1500
t2 = np.linspace(0,fs,n2) # creando un vector de tiempo
print(len(t2))

f = sfft.fftshift(sfft.fftfreq(n=len(t2), d=1./fs))

# Señales VT
S_train_1 = sfft.fftshift(sfft.fft(d_train_1))
SA_train_1 = np.absolute(S_train_1)
SA_train_1 = SA_train_1[:, 1500:3000]

S_test_1 = sfft.fftshift(sfft.fft(d_test_1))
SA_test_1 = np.absolute(S_test_1)
SA_test_1 = SA_test_1[:, 1500:3000]

# Señales LP
S_train_2 = sfft.fftshift(sfft.fft(d_train_2))
SA_train_2 = np.absolute(S_train_2)
SA_train_2 = SA_train_2[:, 1500:3000]

S_test_2 = sfft.fftshift(sfft.fft(d_test_2))
SA_test_2 = np.absolute(S_test_2)
SA_test_2 = SA_test_2[:, 1500:3000]

# Señales Tor
S_train_3 = sfft.fftshift(sfft.fft(d_train_3))
SA_train_3 = np.absolute(S_train_3)
SA_train_3 = SA_train_3[:, 1500:3000]

S_test_3 = sfft.fftshift(sfft.fft(d_test_3))
SA_test_3 = np.absolute(S_test_3)
SA_test_3 = SA_test_3[:, 1500:3000]

print(SA_train_1.shape, SA_test_1.shape)
print(SA_train_2.shape, SA_test_2.shape)
print(SA_train_3.shape, SA_test_3.shape)

# Graficando
plt.figure(3, figsize=(15, 4))
plt.subplot(231)
plt.plot(f, SA_train_1[60])
plt.subplot(232)
plt.plot(f, SA_train_2[18])
plt.subplot(233) 
plt.plot(f, SA_train_3[38])
plt.subplot(234)
plt.plot(f, SA_test_1[44])
plt.subplot(235)
plt.plot(f, SA_test_2[34])
plt.subplot(236)
plt.plot(f, SA_test_3[4])
# Out:
# 1500
# (1480, 1500) (256, 1500)
# (362, 1500) (40, 1500)
# (61, 1500) (6, 1500)

# %% [markdown]
# **1.5 Normalización**

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

# Señales VT
D_train_s1 = min_max_scaler.fit_transform(SA_train_1)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(SA_train_1), np.max(SA_train_1)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s1), np.max(D_train_s1))) 
D_test_s1 = min_max_scaler.transform(SA_test_1)  

# Señales LP
D_train_s2 = min_max_scaler.fit_transform(SA_train_2)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(SA_train_2), np.max(SA_train_2)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s2), np.max(D_train_s2))) 
D_test_s2 = min_max_scaler.transform(SA_test_2)  

# Señales Tor
D_train_s3 = min_max_scaler.fit_transform(SA_train_3)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(SA_train_3), np.max(SA_train_3)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s3), np.max(D_train_s3))) 
D_test_s3 = min_max_scaler.transform(SA_test_3)  

# Graficando
plt.figure(3, figsize=(20, 4))
plt.subplot(231)
plt.plot(t2, D_train_s1[60])
plt.subplot(232)
plt.plot(t2, D_train_s2[18])
plt.subplot(233) 
plt.plot(t2, D_train_s3[38])
plt.subplot(234)
plt.plot(t2, D_test_s1[44])
plt.subplot(235)
plt.plot(t2, D_test_s2[34])
plt.subplot(236)
plt.plot(t2, D_test_s3[4])
# Out:
# Mínimo y máximo originales: 0.0, 125131869.3
# Mínimo y máximo normalizado: 0.0, 1.0
# Mínimo y máximo originales: 0.0, 10438146.7
# Mínimo y máximo normalizado: 0.0, 1.0
# Mínimo y máximo originales: 0.0, 6119343.5
# Mínimo y máximo normalizado: 0.0, 1.0

# %% [markdown]
# # **2. Modelo AutoEncoder para extraer Características (Representaciones de menor dimensión)**

# %% [markdown]
# Importamos TensorFlow 2 que incluye Keras

# %%
# %tensorflow_version 2.x
import tensorflow as tf
print('version de TensorFlow:' + tf.__version__)
# Out:
# version de TensorFlow:2.8.2

# %% [markdown]
# **2.1 Configuración de la arquitectura del Autoencoder**

# %% [markdown]
# Configuramos la arquitectura del modelo de Autoencoder. Esta configuración será reallizada teneindo en cuenta el set de entrenamiento para el conjunto de señales VT.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Activation
from tensorflow.keras import Sequential
from keras.regularizers import l2 # cuando hay sobreajuste la regularización ayuda
# a decartar valores altos en la función de costo. Se puede colocar en cualquier capa
from keras.layers import Dropout  #apagar aleatoriamente algunas neuronas, 
# ayudando a eliminar el sobreajuste
from keras.callbacks import EarlyStopping
np.random.seed(23)

dim_entrada = D_train_s1.shape[1]      
entrada = Input(shape=(dim_entrada,))
print(D_train_s1.shape[1])             

# Encoder
x = Dense(1000, activation='relu', kernel_regularizer=l2(0.005))(entrada)
x = Dropout(0.25)(x)
x = Dense(800, activation='relu', kernel_regularizer=l2(0.005))(x)
x = Dropout(0.25)(x)
x = Dense(400, activation='relu')(x)
x = Dropout(0.25)(x)
encoded = Dense(200, activation='relu', name='bottleneck_layer')(x)

# Decoder 
x = Dense(400, activation='relu')(encoded)
x = Dropout(0.25)(x)
x = Dense(800, activation='relu')(x)
x = Dropout(0.25)(x)
x = Dense(1000, activation='relu', kernel_regularizer=l2(0.005))(x)
x = Dropout(0.25)(x)
decoded = Dense(1500, activation='sigmoid')(x)

# autoencoder = entrada + decoder (que contiene el encoder)
autoencoder = Model(inputs=entrada, outputs=decoded)

autoencoder.summary()
# Out:
# 1500
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1500)]            0
#
#  dense (Dense)               (None, 1000)              1501000
#
#  dropout (Dropout)           (None, 1000)              0
#
#  dense_1 (Dense)             (None, 800)               800800
#
#  dropout_1 (Dropout)         (None, 800)               0
#
#  dense_2 (Dense)             (None, 400)               320400
#
#  dropout_2 (Dropout)         (None, 400)               0
#
#  bottleneck_layer (Dense)    (None, 200)               80200
#
#  dense_3 (Dense)             (None, 400)               80400
#
#  dropout_3 (Dropout)         (None, 400)               0
#
#  dense_4 (Dense)             (None, 800)               320800
#
#  dropout_4 (Dropout)         (None, 800)               0
#
#  dense_5 (Dense)             (None, 1000)              801000
#
#  dropout_5 (Dropout)         (None, 1000)              0
#
#  dense_6 (Dense)             (None, 1500)              1501500
#
# =================================================================
# Total params: 5,406,100
# Trainable params: 5,406,100
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **2.2 Optimización y Entrenamiento**

# %% [markdown]
# La pérdida corresponderá al error absoluto medio(Mean Absolute Error, MAE.
# El optimizador será adam.
# Debido a que el set de datos (entrenamiento y validación) mayor corresponde a las señales sísmicas VT, el autoencoder es entrenado con este set de datos, teniendo en cuenta el desbalance que hay con los demás sets.

# %% [markdown]
# **2.2.1 Entrenando para obtener Representación para Señales VT**

# %% [markdown]
# Una vez entrenado el autoencoder con el set de entenamiento para cada señal, se usa el set de entrenamiento y el set de prueba para obtener las representaciones respectivas de estos dos sets y así permitir conformar nuevos nuevos sets de entrenamiento y validación a partir de las representaciones con menor dimensión.

# %%
autoencoder1 = Model(inputs=entrada, outputs=decoded)
autoencoder1.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
historia = autoencoder1.fit(D_train_s1, D_train_s1,    
                           epochs=25,
                           batch_size=150,
                           validation_data=(D_test_s1, D_test_s1),    
                           shuffle=True)
# Out:
# Epoch 1/25
# 10/10 [==============================] - 4s 32ms/step - loss: 12.1428 - accuracy: 6.7568e-04 - val_loss: 8.6062 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 10/10 [==============================] - 0s 11ms/step - loss: 6.3437 - accuracy: 0.0000e+00 - val_loss: 4.1000 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 10/10 [==============================] - 0s 11ms/step - loss: 2.9867 - accuracy: 6.7568e-04 - val_loss: 1.8641 - val_accuracy: 0.0039
# Epoch 4/25
# 10/10 [==============================] - 0s 10ms/step - loss: 1.3005 - accuracy: 0.0047 - val_loss: 0.7596 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 10/10 [==============================] - 2s 173ms/step - loss: 0.5095 - accuracy: 6.7568e-04 - val_loss: 0.2818 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1828 - accuracy: 6.7568e-04 - val_loss: 0.0986 - val_accuracy: 0.0000e+00
# Epoch 7/25
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0630 - accuracy: 0.0014 - val_loss: 0.0367 - val_accuracy: 0.0000e+00
# Epoch 8/25
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0237 - accuracy: 6.7568e-04 - val_loss: 0.0176 - val_accuracy: 0.0000e+00
# Epoch 9/25
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0123 - accuracy: 0.0014 - val_loss: 0.0125 - val_accuracy: 0.0000e+00
# Epoch 10/25
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0090 - accuracy: 0.0014 - val_loss: 0.0107 - val_accuracy: 0.0000e+00
# Epoch 11/25
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0087 - accuracy: 0.0061 - val_loss: 0.0130 - val_accuracy: 0.0000e+00
# Epoch 12/25
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0108 - accuracy: 0.0345 - val_loss: 0.0127 - val_accuracy: 0.0000e+00
# Epoch 13/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0091 - accuracy: 0.0608 - val_loss: 0.0107 - val_accuracy: 0.0000e+00
# Epoch 14/25
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0078 - accuracy: 0.0750 - val_loss: 0.0093 - val_accuracy: 0.2852
# Epoch 15/25
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0071 - accuracy: 0.1588 - val_loss: 0.0102 - val_accuracy: 0.0000e+00
# Epoch 16/25
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0078 - accuracy: 0.1054 - val_loss: 0.0104 - val_accuracy: 0.2852
# Epoch 17/25
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0077 - accuracy: 0.1176 - val_loss: 0.0100 - val_accuracy: 0.2852
# Epoch 18/25
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0084 - accuracy: 0.1642 - val_loss: 0.0152 - val_accuracy: 0.2852
# Epoch 19/25
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0167 - accuracy: 0.0649 - val_loss: 0.0209 - val_accuracy: 0.0039
# Epoch 20/25
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0161 - accuracy: 0.0162 - val_loss: 0.0153 - val_accuracy: 0.0742
# Epoch 21/25
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0107 - accuracy: 0.0777 - val_loss: 0.0113 - val_accuracy: 0.0742
# Epoch 22/25
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0081 - accuracy: 0.0581 - val_loss: 0.0102 - val_accuracy: 0.0742
# Epoch 23/25
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0083 - accuracy: 0.0642 - val_loss: 0.0130 - val_accuracy: 0.1523
# Epoch 24/25
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0116 - accuracy: 0.0676 - val_loss: 0.0143 - val_accuracy: 0.0039
# Epoch 25/25
# 10/10 [==============================] - 0s 42ms/step - loss: 0.0108 - accuracy: 0.0608 - val_loss: 0.0119 - val_accuracy: 0.1523

# %%
import matplotlib.pyplot as plt
plt.figure(5, figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(historia.history["loss"], label="Pérdida set entrenamiento")
plt.plot(historia.history["val_loss"], label="Pérdida set prueba")
plt.xlabel('Epocas')
plt.legend()
plt.subplot(1,2,2)
plt.plot(historia.history["accuracy"], label="Tasa de acierto en entrenamiento")
plt.plot(historia.history["val_accuracy"], label="Tasa de acierto en teste")
plt.xlabel('Epocas')
plt.legend()

# %% [markdown]
# Una vez entrenado el modelo con el set correspondiente a las señales VT, se extrae la representación contenida en el "bottleneck" del AutoEncoder.

# %%
bottleneck = Model(entrada, encoded)
rep_test_1 = bottleneck.predict(D_test_s1)
rep_train_1 = bottleneck.predict(D_train_s1)
print(rep_test_1.shape)
print(rep_train_1.shape)
# Out:
# (256, 200)
# (1480, 200)

# %% [markdown]
# **2.2.2 Entrenando para obtener Representación para Señales LP**

# %% [markdown]
# Usamos la misma arquitectura del autoencoder, sin embargo, entrenamos con señales LP

# %%
autoencoder2 = Model(inputs=entrada, outputs=decoded)
autoencoder2.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
historia = autoencoder2.fit(D_train_s2, D_train_s2,    
                           epochs=25,
                           batch_size=50,
                           validation_data=(D_test_s2, D_test_s2),    
                           shuffle=True)
# Out:
# Epoch 1/25
# 8/8 [==============================] - 1s 38ms/step - loss: 0.1076 - accuracy: 0.0055 - val_loss: 0.0780 - val_accuracy: 0.0000e+00
# Epoch 2/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0729 - accuracy: 0.0221 - val_loss: 0.0755 - val_accuracy: 0.0750
# Epoch 3/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0695 - accuracy: 0.0166 - val_loss: 0.0723 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0650 - accuracy: 0.0000e+00 - val_loss: 0.0613 - val_accuracy: 0.0250
# Epoch 5/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0554 - accuracy: 0.0138 - val_loss: 0.0723 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0669 - accuracy: 0.0000e+00 - val_loss: 0.0708 - val_accuracy: 0.0250
# Epoch 7/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0654 - accuracy: 0.0028 - val_loss: 0.0698 - val_accuracy: 0.0250
# Epoch 8/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0642 - accuracy: 0.0000e+00 - val_loss: 0.0687 - val_accuracy: 0.0250
# Epoch 9/25
# 8/8 [==============================] - 0s 47ms/step - loss: 0.0634 - accuracy: 0.0055 - val_loss: 0.0682 - val_accuracy: 0.0000e+00
# Epoch 10/25
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0630 - accuracy: 0.0028 - val_loss: 0.0679 - val_accuracy: 0.0000e+00
# Epoch 11/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0627 - accuracy: 0.0608 - val_loss: 0.0677 - val_accuracy: 0.0000e+00
# Epoch 12/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0625 - accuracy: 0.0525 - val_loss: 0.0675 - val_accuracy: 0.0000e+00
# Epoch 13/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0624 - accuracy: 0.0773 - val_loss: 0.0674 - val_accuracy: 0.0000e+00
# Epoch 14/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0623 - accuracy: 0.0055 - val_loss: 0.0673 - val_accuracy: 0.0000e+00
# Epoch 15/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0622 - accuracy: 0.0028 - val_loss: 0.0672 - val_accuracy: 0.0000e+00
# Epoch 16/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0621 - accuracy: 0.0083 - val_loss: 0.0671 - val_accuracy: 0.2500
# Epoch 17/25
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0620 - accuracy: 0.0691 - val_loss: 0.0669 - val_accuracy: 0.0000e+00
# Epoch 18/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0619 - accuracy: 0.0331 - val_loss: 0.0667 - val_accuracy: 0.2500
# Epoch 19/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0850 - accuracy: 0.0442 - val_loss: 0.0833 - val_accuracy: 0.0750
# Epoch 20/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0881 - accuracy: 0.1851 - val_loss: 0.0950 - val_accuracy: 0.2500
# Epoch 21/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0879 - accuracy: 0.2873 - val_loss: 0.0890 - val_accuracy: 0.2500
# Epoch 22/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0804 - accuracy: 0.2873 - val_loss: 0.0804 - val_accuracy: 0.2500
# Epoch 23/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0728 - accuracy: 0.2486 - val_loss: 0.0746 - val_accuracy: 0.0750
# Epoch 24/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0680 - accuracy: 0.1602 - val_loss: 0.0711 - val_accuracy: 0.0750
# Epoch 25/25
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0651 - accuracy: 0.1105 - val_loss: 0.0691 - val_accuracy: 0.0750

# %%
import matplotlib.pyplot as plt
plt.figure(5, figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(historia.history["loss"], label="Pérdida set entrenamiento")
plt.plot(historia.history["val_loss"], label="Pérdida set prueba")
plt.xlabel('Epocas')
plt.legend()
plt.subplot(1,2,2)
plt.plot(historia.history["accuracy"], label="Tasa de acierto en entrenamiento")
plt.plot(historia.history["val_accuracy"], label="Tasa de acierto en teste")
plt.xlabel('Epocas')
plt.legend()

# %% [markdown]
# Una vez entrenado el modelo con el set correspondiente a las señales LP, se extrae la representación contenida en el "bottleneck" del AutoEncoder.

# %%
bottleneck = Model(entrada, encoded)
rep_test_2 = bottleneck.predict(D_test_s2)
print(rep_test_2.shape)
rep_train_2 = bottleneck.predict(D_train_s2)
print(rep_train_2.shape)
# Out:
# (40, 200)
# (362, 200)

# %% [markdown]
# **2.2.3 Entrenando para obtener Representación para Señales Tor**

# %% [markdown]
# Usamos la misma arquitectura del autoencoder, sin embargo, entrenamos con señales Tor

# %%
autoencoder3 = Model(inputs=entrada, outputs=decoded)
autoencoder3.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
historia = autoencoder3.fit(D_train_s3, D_train_s3,    
                           epochs=25,
                           batch_size=2,
                           validation_data=(D_test_s3, D_test_s3),    
                           shuffle=True)
# Out:
# Epoch 1/25
# 31/31 [==============================] - 3s 80ms/step - loss: 0.1239 - accuracy: 0.0164 - val_loss: 0.1516 - val_accuracy: 0.1667
# Epoch 2/25
# 31/31 [==============================] - 0s 7ms/step - loss: 0.1239 - accuracy: 0.0164 - val_loss: 0.1425 - val_accuracy: 0.0000e+00
# Epoch 3/25
# 31/31 [==============================] - 0s 6ms/step - loss: 0.1302 - accuracy: 0.0164 - val_loss: 0.1436 - val_accuracy: 0.0000e+00
# Epoch 4/25
# 31/31 [==============================] - 1s 48ms/step - loss: 0.1360 - accuracy: 0.0000e+00 - val_loss: 0.1460 - val_accuracy: 0.0000e+00
# Epoch 5/25
# 31/31 [==============================] - 1s 45ms/step - loss: 0.1353 - accuracy: 0.0000e+00 - val_loss: 0.1422 - val_accuracy: 0.0000e+00
# Epoch 6/25
# 31/31 [==============================] - 0s 6ms/step - loss: 0.1159 - accuracy: 0.0000e+00 - val_loss: 0.1311 - val_accuracy: 0.0000e+00
# Epoch 7/25
# 31/31 [==============================] - 0s 6ms/step - loss: 0.1267 - accuracy: 0.0000e+00 - val_loss: 0.1431 - val_accuracy: 0.0000e+00
# Epoch 8/25
# 31/31 [==============================] - 0s 6ms/step - loss: 0.1127 - accuracy: 0.0000e+00 - val_loss: 0.1290 - val_accuracy: 0.0000e+00
# Epoch 9/25
# 31/31 [==============================] - 0s 15ms/step - loss: 0.1101 - accuracy: 0.0000e+00 - val_loss: 0.1414 - val_accuracy: 0.0000e+00
# Epoch 10/25
# 31/31 [==============================] - 0s 6ms/step - loss: 0.1121 - accuracy: 0.0000e+00 - val_loss: 0.1327 - val_accuracy: 0.0000e+00
# Epoch 11/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1180 - accuracy: 0.0000e+00 - val_loss: 0.1287 - val_accuracy: 0.0000e+00
# Epoch 12/25
# 31/31 [==============================] - 0s 13ms/step - loss: 0.1069 - accuracy: 0.0000e+00 - val_loss: 0.1234 - val_accuracy: 0.0000e+00
# Epoch 13/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.1051 - accuracy: 0.0000e+00 - val_loss: 0.1221 - val_accuracy: 0.0000e+00
# Epoch 14/25
# 31/31 [==============================] - 0s 6ms/step - loss: 0.1055 - accuracy: 0.0000e+00 - val_loss: 0.1322 - val_accuracy: 0.0000e+00
# Epoch 15/25
# 31/31 [==============================] - 0s 6ms/step - loss: 0.1006 - accuracy: 0.0492 - val_loss: 0.1177 - val_accuracy: 0.0000e+00
# Epoch 16/25
# 31/31 [==============================] - 1s 17ms/step - loss: 0.0976 - accuracy: 0.0000e+00 - val_loss: 0.1324 - val_accuracy: 0.0000e+00
# Epoch 17/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0961 - accuracy: 0.0000e+00 - val_loss: 0.1144 - val_accuracy: 0.0000e+00
# Epoch 18/25
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0932 - accuracy: 0.0000e+00 - val_loss: 0.1151 - val_accuracy: 0.0000e+00
# Epoch 19/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0930 - accuracy: 0.0000e+00 - val_loss: 0.1217 - val_accuracy: 0.0000e+00
# Epoch 20/25
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0942 - accuracy: 0.0000e+00 - val_loss: 0.1155 - val_accuracy: 0.0000e+00
# Epoch 21/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0911 - accuracy: 0.0000e+00 - val_loss: 0.1140 - val_accuracy: 0.0000e+00
# Epoch 22/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0902 - accuracy: 0.0000e+00 - val_loss: 0.1227 - val_accuracy: 0.0000e+00
# Epoch 23/25
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0922 - accuracy: 0.0000e+00 - val_loss: 0.1149 - val_accuracy: 0.0000e+00
# Epoch 24/25
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0888 - accuracy: 0.0000e+00 - val_loss: 0.1105 - val_accuracy: 0.0000e+00
# Epoch 25/25
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0926 - accuracy: 0.0164 - val_loss: 0.1100 - val_accuracy: 0.0000e+00

# %%
import matplotlib.pyplot as plt
plt.figure(5, figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(historia.history["loss"], label="Pérdida set entrenamiento")
plt.plot(historia.history["val_loss"], label="Pérdida set prueba")
plt.xlabel('Epocas')
plt.legend()
plt.subplot(1,2,2)
plt.plot(historia.history["accuracy"], label="Tasa de acierto en entrenamiento")
plt.plot(historia.history["val_accuracy"], label="Tasa de acierto en teste")
plt.xlabel('Epocas')
plt.legend()

# %% [markdown]
# Una vez entrenado el modelo con el set correspondiente a las señales Tor, se extrae la representación contenida en el "bottleneck" del AutoEncoder.

# %%
bottleneck = Model(entrada, encoded)
rep_test_3 = bottleneck.predict(D_test_s3)
print(rep_test_3.shape)
rep_train_3 = bottleneck.predict(D_train_s3)
print(rep_train_3.shape)
# Out:
# (6, 200)
# (61, 200)

# %% [markdown]
# **2.3. Representaciones de menor Dimensión**

# %% [markdown]
# Una vez entrenado el autoencoder extraemos la información aprendida de la capa de menor dimensión, la cual consigue representar mejor la señal.
#
# A continuación se presenta una representación por cada tipo de señal solo para poder identificar las diferntes representaciones obtenidas.

# %%
Representación = Model(inputs=entrada, outputs=encoded)
Representación.summary

# Observamos cómo el Autoencoder consigue representar 

dato = 5    # Elegimos un dato al azar de los registro de los data sets de validación
# El data set con el menor número de datos de validación es para la señal Tor con 6 ejemplos.

plt.figure(figsize=(15,5))
plt.subplot(3,2,1)
plt.plot(rep_train_1[dato])
plt.legend(labels=["Train VT"])
plt.subplot(3,2,2)
plt.plot(rep_test_1[dato])
plt.legend(labels=["Test VT"])
plt.subplot(3,2,3)
plt.plot(rep_train_2[dato])
plt.legend(labels=["Train LP"])
plt.subplot(3,2,4)
plt.plot(rep_test_2[dato])
plt.legend(labels=["Test LP"])
plt.subplot(3,2,5)
plt.plot(rep_train_3[dato])
plt.legend(labels=["Rain Tor"])
plt.subplot(3,2,6)
plt.plot(rep_test_3[dato])
plt.legend(labels=["Test Tor"])

# %% [markdown]
# # **3. Modelo de AutoEncoder para Clasificación**

# %% [markdown]
# Con las representaciones obtenidas con el modelo de autoencoder anterior, estas son normalizadas y presentadas a un nuevo autoencoder para su posterior clasificación bajo el enfoque de distribución del error de reconstrucción.

# %% [markdown]
# **3.1 Normalización de las representaciones**

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

# Señales VT
Rep_train_s1 = min_max_scaler.fit_transform(rep_train_1)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(rep_train_1), np.max(rep_train_1)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(Rep_train_s1), np.max(Rep_train_s1))) 
Rep_test_s1 = min_max_scaler.transform(rep_test_1)  

# Señales LP
Rep_train_s2 = min_max_scaler.fit_transform(rep_train_2)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(rep_train_2), np.max(rep_train_2)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s2), np.max(D_train_s2))) 
Rep_test_s2 = min_max_scaler.transform(rep_test_2)  

# Señales Tor
Rep_train_s3 = min_max_scaler.fit_transform(rep_train_3)
print('Mínimo y máximo originales: {:.1f}, {:.1f}'.format(np.min(rep_train_3), np.max(rep_train_3)))      
print('Mínimo y máximo normalizado: {:.1f}, {:.1f}'.format(np.min(D_train_s3), np.max(D_train_s3))) 
Rep_test_s3 = min_max_scaler.transform(rep_test_3)  

# Graficando
n3 = Rep_train_s1.shape[1]
t3 = np.linspace(0,fs,n3) # creando un vector de tiempo
print(len(t3))
plt.figure(figsize=(20, 4))
plt.subplot(231)
plt.plot(t3, Rep_train_s1[60])
plt.legend(labels=["Train VT"])
plt.subplot(232)
plt.plot(t3, Rep_train_s2[18])
plt.legend(labels=["Train LP"])
plt.subplot(233) 
plt.plot(t3, Rep_train_s3[38])
plt.legend(labels=["Train Tor"])
plt.subplot(234)
plt.plot(t3, Rep_test_s1[44])
plt.legend(labels=["Test VT"])
plt.subplot(235)
plt.plot(t3, Rep_test_s2[34])
plt.legend(labels=["Test VT"])
plt.subplot(236)
plt.plot(t3, Rep_test_s3[4])
plt.legend(labels=["Test VT"])
# Out:
# Mínimo y máximo originales: 0.0, 2.6
# Mínimo y máximo normalizado: 0.0, 0.0
# Mínimo y máximo originales: 0.0, 3.7
# Mínimo y máximo normalizado: 0.0, 1.0
# Mínimo y máximo originales: 0.0, 0.7
# Mínimo y máximo normalizado: 0.0, 1.0
# 200

# %% [markdown]
# **3.2 Modelo de AutoEncoder para posterior Clasificación**

# %% [markdown]
# A continuación se configura la arquitectura del AutoEncoder para que este aprenda la reconstrucción con el set de datos de entrenamiento para las señales VT que es de la cual se tiene un set con un mayor número de ejemplos.

# %%
np.random.seed(23)

dim_entrada = Rep_train_s1.shape[1]      
entrada = Input(shape=(dim_entrada,))
print(Rep_train_s1.shape[1])             

# Encoder
x = Dense(150, activation='relu', kernel_regularizer=l2(0.005))(entrada)
x = Dropout(0.25)(x)
x = Dense(100, activation='relu', kernel_regularizer=l2(0.005))(x)
x = Dropout(0.25)(x)
encoded = Dense(50, activation='relu', name='bottleneck_layer')(x)

# Decoder 
x = Dense(100, activation='relu')(encoded)
x = Dropout(0.25)(x)
x = Dense(150, activation='relu')(x)
x = Dropout(0.25)(x)
decoded = Dense(200, activation='sigmoid')(x)

# autoencoder = entrada + decoder (que contiene el encoder)
autoencoder = Model(inputs=entrada, outputs=decoded)

autoencoder.summary()
# Out:
# 200
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200)]             0
#
#  dense_7 (Dense)             (None, 150)               30150
#
#  dropout_6 (Dropout)         (None, 150)               0
#
#  dense_8 (Dense)             (None, 100)               15100
#
#  dropout_7 (Dropout)         (None, 100)               0
#
#  bottleneck_layer (Dense)    (None, 50)                5050
#
#  dense_9 (Dense)             (None, 100)               5100
#
#  dropout_8 (Dropout)         (None, 100)               0
#
#  dense_10 (Dense)            (None, 150)               15150
#
#  dropout_9 (Dropout)         (None, 150)               0
#
#  dense_11 (Dense)            (None, 200)               30200
#
# =================================================================
# Total params: 100,750
# Trainable params: 100,750
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **3.3 Optimización y Entrenamiento**

# %% [markdown]
# Lapérdida corresponderá al error absoluto medio (MAE) y el optimizador será adam.

# %%
autoencoder.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
historia = autoencoder.fit(Rep_train_s1, Rep_train_s1,    
                           epochs=20,
                           batch_size=150,
                           validation_data=(Rep_test_s1, Rep_test_s1),    
                           shuffle=True)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 1s 21ms/step - loss: 1.8175 - accuracy: 0.0027 - val_loss: 1.6550 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 10/10 [==============================] - 0s 6ms/step - loss: 1.5285 - accuracy: 6.7568e-04 - val_loss: 1.3647 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 10/10 [==============================] - 0s 6ms/step - loss: 1.1995 - accuracy: 0.0041 - val_loss: 0.9520 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7534 - accuracy: 0.0020 - val_loss: 0.5760 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.5152 - accuracy: 0.0122 - val_loss: 0.4460 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3991 - accuracy: 0.0135 - val_loss: 0.3445 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3070 - accuracy: 0.0236 - val_loss: 0.2637 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2343 - accuracy: 0.0169 - val_loss: 0.2004 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1776 - accuracy: 0.0182 - val_loss: 0.1513 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1337 - accuracy: 0.0169 - val_loss: 0.1135 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1000 - accuracy: 0.0230 - val_loss: 0.0846 - val_accuracy: 0.0000e+00
# Epoch 12/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0743 - accuracy: 0.0203 - val_loss: 0.0626 - val_accuracy: 0.0000e+00
# Epoch 13/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0549 - accuracy: 0.0243 - val_loss: 0.0461 - val_accuracy: 0.0000e+00
# Epoch 14/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0403 - accuracy: 0.0196 - val_loss: 0.0337 - val_accuracy: 0.0000e+00
# Epoch 15/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0294 - accuracy: 0.0182 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 16/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0213 - accuracy: 0.0189 - val_loss: 0.0177 - val_accuracy: 0.0000e+00
# Epoch 17/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0153 - accuracy: 0.0230 - val_loss: 0.0127 - val_accuracy: 0.0000e+00
# Epoch 18/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0110 - accuracy: 0.0155 - val_loss: 0.0090 - val_accuracy: 0.0000e+00
# Epoch 19/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.0236 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 20/20
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.0236 - val_loss: 0.0045 - val_accuracy: 0.0000e+00

# %%
import matplotlib.pyplot as plt
plt.figure(5, figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(historia.history["loss"], label="Pérdida set entrenamiento")
plt.plot(historia.history["val_loss"], label="Pérdida set prueba")
plt.xlabel('Epocas')
plt.legend()
plt.subplot(1,2,2)
plt.plot(historia.history["accuracy"], label="Tasa de acierto en entrenamiento")
plt.plot(historia.history["val_accuracy"], label="Tasa de acierto en teste")
plt.xlabel('Epocas')
plt.legend()

# %% [markdown]
# # **4. Clasificación**

# %% [markdown]
# Identificamos qué tan bien el modelo es capaz de reconstruir las señales para las cuales fue entrenado (VT) como también las otras señales de tal forma que se pueda identificar el error de reconstrucción.

# %% [markdown]
# **3.1 Identificación de la distribución del error**

# %%
rec_1 = autoencoder(Rep_test_s1).numpy()
rec_2 = autoencoder(Rep_test_s2).numpy()
rec_3 = autoencoder(Rep_test_s3).numpy()

dato = 5    # Elegimos un dato al azar de los registro de los data sets de validación
# El data set con el menor número de datos de validación es para la señal Tor con 6 ejemplos.

plt.figure(figsize=(15,5))
plt.subplot(3,1,1)
plt.plot(Rep_test_s1[dato],'b')
plt.plot(rec_1[dato],'r')
plt.fill_between(np.arange(200), rec_1[dato], Rep_test_s1[dato], color='lightcoral')
plt.legend(labels=["Original normal", "Reconstruction", "Error"])
plt.subplot(3,1,2)
plt.plot(Rep_test_s2[dato],'b')
plt.plot(rec_2[dato],'r')
plt.fill_between(np.arange(200), rec_2[dato], Rep_test_s2[dato], color='lightcoral')
plt.legend(labels=["Original anormal", "Reconstruction", "Error"])
plt.subplot(3,1,3)
plt.plot(Rep_test_s3[dato],'b')
plt.plot(rec_3[dato],'r')
plt.fill_between(np.arange(200), rec_3[dato], Rep_test_s3[dato], color='lightcoral')
plt.legend(labels=["Original anormal", "Reconstruction", "Error"])

# %%
rec_1 = autoencoder.predict(Rep_test_s1)
rec_2 = autoencoder.predict(Rep_test_s2)
rec_3 = autoencoder.predict(Rep_test_s3)

loss_1 = tf.keras.losses.mae(rec_1, Rep_test_s1)
loss_2 = tf.keras.losses.mae(rec_2, Rep_test_s2)
loss_3 = tf.keras.losses.mae(rec_3, Rep_test_s3)

plt.figure(figsize=(15,8))
plt.hist(loss_1[None,:], bins=100, alpha=0.75, label='VT (1)')
plt.hist(loss_2[None,:], bins=100, alpha=0.75, color='#ff521b', label='LP (2)')
plt.hist(loss_3[None,:], bins=100, alpha=0.75, color='#020122', label='Tor (3)')

plt.xlabel('Pérdidas (MAE)')
plt.ylabel('Nro. ejemplos')
plt.legend(loc='upper right')
plt.vlines(0.08,0,70,'k')

# %% [markdown]
# **3.2 Definición del humbral de clasificación**

# %%
umbral = np.mean(loss_1) + np.std(loss_1)
print("Umbral: ", umbral)
# Out:
# Umbral:  2.7532187e-06

# %% [markdown]
# **3.3 Sensitividad y Especificidad**

# %% [markdown]
# *   **Verdaderos positivos (TP):** anormales que han sido correctamente clasificados como anormales
# *   **Falsos negativos (FN):** anormales que han sido clasificados erróneamente como normales
# *   **Verdaderos negativos (TN):** normales que han sido correctamente clasificados como normales
# *   **Falsos positivos (FP):** normales que han sido clasificados erróneamente como anormales

# %% [markdown]
# La **sensitividad** mide la proporción de anormales que fueron detectados correctamente como anormales. Una sensitividad del 100% detectará a todos los pacientes enfermos:
#
# $$Sensitividad = \dfrac{TP}{TP+FN}$$
#
# La **especificidad** mide la proporción de normales que fueron detectados correctamente como normales. Una especificidad del 100% detectará a todos los pacientes sanos:
# $$Especificidad = \dfrac{TN}{TN+FP}$$

# %%
# Definiendo funciones para la clasificación individual
def identificar(modelo, datos, umbral):
  reconstrucciones = modelo(datos)
  perdida = tf.keras.losses.mae(reconstrucciones, datos)
  return tf.math.less(perdida, umbral)

def calcular_sensitividad(identificacion, titulo):
  TP = np.count_nonzero(~identificacion)
  FN = np.count_nonzero(identificacion)
  sen = 100*(TP/(TP+FN))

  print(titulo + ': {:.1f}%'.format(sen))

def calcular_especificidad(identificacion, titulo):
  TN = np.count_nonzero(identificacion)
  FP = np.count_nonzero(~identificacion)
  esp = 100*(TN/(TN+FP))

  print(titulo + ': {:.1f}%'.format(esp))
  return esp

# %%
# Identificación del tipo de señal
pred_1 = identificar(autoencoder, Rep_test_s1, umbral)
pred_2 = identificar(autoencoder, Rep_test_s2, umbral)
pred_3 = identificar(autoencoder, Rep_test_s3, umbral)

# Calculo de Especificidad
esp_1 = calcular_especificidad(pred_1,'Especificidad (cat. VT, VT)')

# Cálculo de Sensitividad
sen_2 = calcular_sensitividad(pred_2,'Sensitividad (cat. LP, NO VTs)')
sen_3 = calcular_sensitividad(pred_3,'Sensitividad (cat. Tor, NO VTs)')
# Out:
# Especificidad (cat. VT, VT): 98.0%
# Sensitividad (cat. LP, NO VTs): 100.0%
# Sensitividad (cat. Tor, NO VTs): 100.0%

# %% [markdown]
# **3.3 Clasificador II para las señales restantes: LP y Tor**

# %% [markdown]
# Optimización y entrenamiento

# %%
autoencoder.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
historia = autoencoder.fit(Rep_train_s2, Rep_train_s2,    
                           epochs=15,
                           batch_size=30,
                           validation_data=(Rep_test_s2, Rep_test_s2),    
                           shuffle=True)
# Out:
# Epoch 1/15
# 13/13 [==============================] - 2s 19ms/step - loss: 0.0763 - accuracy: 0.0000e+00 - val_loss: 0.0830 - val_accuracy: 0.0000e+00
# Epoch 2/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0546 - accuracy: 0.0000e+00 - val_loss: 0.0528 - val_accuracy: 0.0000e+00
# Epoch 3/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0387 - accuracy: 0.0055 - val_loss: 0.0234 - val_accuracy: 0.0000e+00
# Epoch 4/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0313 - accuracy: 0.0000e+00 - val_loss: 0.0296 - val_accuracy: 0.0000e+00
# Epoch 5/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0305 - accuracy: 0.0166 - val_loss: 0.0184 - val_accuracy: 0.0000e+00
# Epoch 6/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0272 - accuracy: 0.0055 - val_loss: 0.0201 - val_accuracy: 0.0000e+00
# Epoch 7/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.0110 - val_loss: 0.0163 - val_accuracy: 0.0000e+00
# Epoch 8/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0258 - accuracy: 0.0055 - val_loss: 0.0269 - val_accuracy: 0.0000e+00
# Epoch 9/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0259 - accuracy: 0.0055 - val_loss: 0.0160 - val_accuracy: 0.0000e+00
# Epoch 10/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0257 - accuracy: 0.0000e+00 - val_loss: 0.0264 - val_accuracy: 0.0000e+00
# Epoch 11/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0257 - accuracy: 0.0028 - val_loss: 0.0132 - val_accuracy: 0.0000e+00
# Epoch 12/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0237 - accuracy: 0.0055 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 13/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0252 - accuracy: 0.0028 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 14/15
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0239 - accuracy: 0.0166 - val_loss: 0.0132 - val_accuracy: 0.0000e+00
# Epoch 15/15
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0234 - accuracy: 0.0138 - val_loss: 0.0143 - val_accuracy: 0.0000e+00

# %%
import matplotlib.pyplot as plt
plt.figure(5, figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(historia.history["loss"], label="Pérdida set entrenamiento")
plt.plot(historia.history["val_loss"], label="Pérdida set prueba")
plt.xlabel('Epocas')
plt.legend()
plt.subplot(1,2,2)
plt.plot(historia.history["accuracy"], label="Tasa de acierto en entrenamiento")
plt.plot(historia.history["val_accuracy"], label="Tasa de acierto en teste")
plt.xlabel('Epocas')
plt.legend()

# %%
rec_2 = autoencoder(Rep_test_s2).numpy()
rec_3 = autoencoder(Rep_test_s3).numpy()

dato = 5    # Elegimos un dato al azar de los registro de los data sets de validación
# El data set con el menor número de datos de validación es para la señal Tor con 6 ejemplos.

plt.figure(figsize=(15,5))
plt.subplot(2,1,1)
plt.plot(Rep_test_s2[dato],'b')
plt.plot(rec_2[dato],'r')
plt.fill_between(np.arange(200), rec_2[dato], Rep_test_s2[dato], color='lightcoral')
plt.legend(labels=["Original anormal", "Reconstruction", "Error"])
plt.subplot(2,1,2)
plt.plot(Rep_test_s3[dato],'b')
plt.plot(rec_3[dato],'r')
plt.fill_between(np.arange(200), rec_3[dato], Rep_test_s3[dato], color='lightcoral')
plt.legend(labels=["Original anormal", "Reconstruction", "Error"])

# %%
rec_2 = autoencoder.predict(Rep_test_s2)
rec_3 = autoencoder.predict(Rep_test_s3)

loss_2 = tf.keras.losses.mae(rec_2, Rep_test_s2)
loss_3 = tf.keras.losses.mae(rec_3, Rep_test_s3)

plt.figure(figsize=(15,8))
plt.hist(loss_2[None,:], bins=100, alpha=0.75, color='#ff521b', label='LP (2)')
plt.hist(loss_3[None,:], bins=100, alpha=0.75, color='#020122', label='Tor (3)')

plt.xlabel('Pérdidas (MAE)')
plt.ylabel('Nro. ejemplos')
plt.legend(loc='upper right')
plt.vlines(0.08,0,70,'k')

# %%
umbral = np.mean(loss_2) + np.std(loss_2)
print("Umbral: ", umbral)
# Out:
# Umbral:  0.034417804

# %%
# Identificación del tipo de señal
pred_2 = identificar(autoencoder, Rep_test_s2, umbral)
pred_3 = identificar(autoencoder, Rep_test_s3, umbral)

# Calculo de Especificidad
esp_2 = calcular_especificidad(pred_2,'Especificidad (cat. LP, LP)')

# Cálculo de Sensitividad
sen_3 = calcular_sensitividad(pred_3,'Sensitividad (cat. Tor, NO LPs)')
# Out:
# Especificidad (cat. LP, LP): 92.5%
# Sensitividad (cat. Tor, NO LPs): 100.0%
